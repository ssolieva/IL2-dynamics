# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
#     S1:
#     mini-beta: 0.14197345224330166
#     pack-beta: 0.14740291857680984
#     mini-b: 0.17257669957290847
#     b-beta: 0.8939108314949373
#     S15:
#     mini-beta: 0.09033551082457165
#     pack-beta: 0.07412884540500768
#     mini-b: 0.13719491633664213
#     b-beta: 0.17503386739747628
#     wt:
#     mini-beta: 0.0888642119496894
#     pack-beta: 0.1577866177524193
#     mini-b: 0.0922494707007728
#     b-beta: 0.40720197410550457

# %%
WT = [0.0888642119496894, 0.1577866177524193, 0.0922494707007728, 0.40720197410550457]
S15= [0.09033551082457165,0.07412884540500768,0.13719491633664213,0.17503386739747628]
S1 = [0.14197345224330166,0.14740291857680984,0.17257669957290847,0.8939108314949373]

# %%
plt.figure(figsize=[5,3])
plt.bar(np.array([0,5,10,15]),   WT, color = '#888985', edgecolor = 'k', label = 'WT')
plt.bar(np.array([0,5,10,15])+1, S15,color = '#5AC8E0', edgecolor = 'k', label = 'S15')
plt.bar(np.array([0,5,10,15])+2, S1, color = '#BC60A5', edgecolor = 'k', label = 'S1')
plt.legend()
plt.xticks(np.array([0,5,10,15])+1, ['mini_to_beta', 'pack_to_beta', 'mini_to_bhelix', 'bhelix_to_beta'], fontsize=11, rotation=45, weight='bold')

plt.yticks(fontsize=12, weight='bold')
plt.tight_layout()
plt.savefig('../figures/cards_grouped.pdf', transparent=True, dpi=300)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
